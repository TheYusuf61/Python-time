# %%
sayi1=20
type(sayi1)
# Out:
# int

# %%
sayi2="20"
type(sayi2)
# Out:
# str

# %%
sayi1
# Out:
# 20

# %%
sayi3=float(sayi1)
sayi3
# Out:
# 20.0

# %%
sayi2
# Out:
# '20'

# %%
sayi3=str(sayi3)
sayi3
# Out:
# '20.0'

# %%
deneme=4444
 deneme[1]
# Out:
#   Cell In[8], line 2
#     deneme[1]
#     ^
# IndentationError: unexpected indent

# %%
deneme="4444"
deneme[1]
# Out:
# '4'

# %%
rakam=8161
rakam=str(rakam)
x1=int(rakam[2])
x2=int(rakam[3])
toplam=x1+x2
print(toplam)
# Out:
# 7

# %%
isim=13
print(isim)
# Out:
# 13

# %%
deneme1=str(isim)
x1=int(deneme1[0])
x2=int(deneme1[1])
çarpım=x1*x2
print(çarpım)
# Out:
# 3

# %%
print("selamün aleyküm\n github")
# Out:
# selamün aleyküm
#  github

# %%
print("""eski adamlar
doğruyu söylemiş""")
# Out:
# eski adamlar
# doğruyu söylemiş

# %%
print("github\tpython")
# Out:
# github	python

# %%
print("29","05","1453")
# Out:
# 29 05 1453

# %%
print("29","05","1453",sep=".")
# Out:
# 29.05.1453

# %%
print(*"github")
# Out:
# g i t h u b

# %%
print(*"github",sep=";")
# Out:
# g;i;t;h;u;b

# %%
print(*"TBMM",sep=".")
# Out:
# T.B.M.M

# %%
kod1="elveda"
kod2="github"
print("bugünlük {} {} sonra görüşürüz".format(kod1,kod2))
# Out:
# bugünlük elveda github sonra görüşürüz
