# %%
liste=["armut","apple","water lemon"]
print(liste)
# Out:
# ['armut', 'apple', 'water lemon']

# %%
liste1=list(("ayva","phone","turp"))
print(liste1)
# Out:
# ['ayva', 'phone', 'turp']

# %%
print(liste1[:])
# Out:
# ['ayva', 'phone', 'turp']

# %%
print(liste[0:2])
# Out:
# ['armut', 'apple']

# %%
print(liste[::2])
# Out:
# ['armut', 'water lemon']

# %%
a = [1,2,3,4]
b = a
b.append(5)
print(a)
# Out:
# [1, 2, 3, 4, 5]

# %%
len(liste)
# Out:
# 3

# %%
if "apple" in liste:
    print("evet listede var")

else:
   print("bugünlük gerek yok:) ")
# Out:
# evet listede var

# %%
b.pop(4)
print(b)
# Out:
# [1, 2, 3, 4]

# %%
b.pop()
print(b)
# Out:
# [1, 2, 3]

# %%
isimler=["ahmet","mehmet","max"]
isimler.sort()
print(isimler)
# Out:
# ['ahmet', 'max', 'mehmet']
