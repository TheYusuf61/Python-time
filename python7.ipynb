# %%
puan=int(input("lütfen puanı girin:"))
kazanmak_sıra=int(input("lütfen sıra aralığını girin:"))
if  puan >= 85  and  kazanmak_sıra >= 15000:
    print("tebrikler puanınız yeterli! kazandınız:")
else:
     print("üzgünüz puanınız el vermedi:")

print("tebrikler puanınız {},sıralamanız {} :".format(puan,kazanmak_sıra))
# Out:
# lütfen puanı girin: 88
# lütfen sıra aralığını girin: 1222
# üzgünüz puanınız el vermedi:
# tebrikler puanınız 88,sıralamanız 1222 :

# %%
puan=int(input("lütfen puanı girin:"))
kazanmak_sıra=int(input("lütfen sıra aralığını girin:"))
print("tebrikler puanınız {},sıralamanız {} :".format(puan,kazanmak_sıra))
if  puan >= 85  and  kazanmak_sıra <= 15000:
    print("tebrikler puanınız yeterli! kazandınız")

else:
    print("üzgünüz puanınız el vermedi")
# Out:
# lütfen puanı girin: 88
# lütfen sıra aralığını girin: 12222
# tebrikler puanınız 88,sıralamanız 12222 :
# tebrikler puanınız yeterli! kazandınız

# %%
yaş=int(input("yaşınız kaç:"))
boy=int(input("boyunzu kaç:"))
print("yaşı {} boyu {} :".format(yaş,boy))
if 21 < yaş and yaş< 33 and 167 < boy and boy < 183 :
     print("Sizi arayacağız")

else:
     print("sizinle çalışamayız")
# Out:
# yaşınız kaç: 22
# boyunzu kaç: 176
# yaşı 22 boyu 176 :
# Sizi arayacağız
