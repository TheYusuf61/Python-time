# %%
5 in [3,4,5,2]
# Out:
# True

# %%
5 in [1,2,4]
# Out:
# False

# %%
"g" in "github"
# Out:
# True

# %%
"a" in "github"
# Out:
# False

# %%
liste=[1,2,3,4,5]
for eleman in liste:
    print(eleman)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
sonuç=0
for i in liste:
    sonuç+=i
print(sonuç)
# Out:
# 15

# %%
liste1=[11,22,33,44,55,66]
çift=[]
tek=[]
for i in liste1:
    if(i%2==0):
        çift.append(i)
    else:
        tek.append(i)
print("tek sayılar{}, çift sayılar {}".format(tek,çift))
# Out:
# tek sayılar[11, 33, 55], çift sayılar [22, 44, 66]

# %%
isim="yusuf"
sayaç=0
for i in isim:
    if(i=="s"):
        sayaç+=1
print("{} değişkeninde {} kadar 's' vardır".format(isim,sayaç))
# Out:
# yusuf değişkeninde 1 kadar 's' vardır

# %%
for deneme in range(100):
    print("şifre deneniyor:", deneme)
# Out:
# şifre deneniyor: 0
# şifre deneniyor: 1
# şifre deneniyor: 2
# şifre deneniyor: 3
# şifre deneniyor: 4
# şifre deneniyor: 5
# şifre deneniyor: 6
# şifre deneniyor: 7
# şifre deneniyor: 8
# şifre deneniyor: 9
# şifre deneniyor: 10
# şifre deneniyor: 11
# şifre deneniyor: 12
# şifre deneniyor: 13
# şifre deneniyor: 14
# şifre deneniyor: 15
# şifre deneniyor: 16
# şifre deneniyor: 17
# şifre deneniyor: 18
# şifre deneniyor: 19
# şifre deneniyor: 20
# şifre deneniyor: 21
# şifre deneniyor: 22
# şifre deneniyor: 23
# şifre deneniyor: 24
# şifre deneniyor: 25
# şifre deneniyor: 26
# şifre deneniyor: 27
# şifre deneniyor: 28
# şifre deneniyor: 29
# şifre deneniyor: 30
# şifre deneniyor: 31
# şifre deneniyor: 32
# şifre deneniyor: 33
# şifre deneniyor: 34
# şifre deneniyor: 35
# şifre deneniyor: 36
# şifre deneniyor: 37
# şifre deneniyor: 38
# şifre deneniyor: 39
# şifre deneniyor: 40
# şifre deneniyor: 41
# şifre deneniyor: 42
# şifre deneniyor: 43
# şifre deneniyor: 44
# ...

# %%
düzenek=0
sinyal=[20,30,51,49,60,200,10]
for deneme in sinyal:
    if(deneme>50):
        print("tehlikeli sinyal:" ,deneme)
        düzenek+=1
else:
    print("temiz:", deneme)
print("toplam tehlike:", düzenek)
# Out:
# tehlikeli sinyal: 51
# tehlikeli sinyal: 60
# tehlikeli sinyal: 200
# temiz: 10
# toplam tehlike: 3

# %%
puanlar={
"aykut": 71,"mehmet": 63,"yusuf": 75}
print("---geçenler 70 üstü---")
for isim in puanlar:
    notu=puanlar[isim]
    if notu > 70:
     print("tebrikler:",isim,"puan:", notu)
# Out:
# ---geçenler 70 üstü---
# tebrikler: aykut puan: 71
# tebrikler: yusuf puan: 75

# %%
skor={
"a spor": 36, "b spor": 33, "c spor": 37}
print("şampiyon")
for i in skor:
     winner=skor[i]
     if winner > 36:
        print("tebrikler:",i,"puan",winner)
# Out:
# şampiyon
# tebrikler: c spor puan 37

# %%
düzenek=0
yas=[
10,12,13,16,18]
for i in yas:
     if i > 14:
       print("yası uygundur:",i)
# Out:
# yası uygundur: 16
# yası uygundur: 18
