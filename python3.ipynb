# %%
print("alışveriş listesi")
ürün1=input("alınacak şeyi giriniz")
ürün2=input("lütfen nereden alınacağını giriniz")
ürün3=int(input("lütfen parasını giriniz"))
ürün4=int(input("lütfen sayısını giriniz"))
liste=[ürün1,ürün2,ürün3,ürün4]
print("bilgiler kayıt ediliyor")
print("""ürünün adı:{}
ürünün satıldığı yer:{}
ürünün fiyatı:{}
ürünün sayısı:{}""".format(ürün1,ürün2,ürün3,ürün4))
print("bilgiler kayıt edildi")
toplam_tutar=ürün3*ürün4
print("toplam borç:{} tl".format(toplam_tutar))
# Out:
# alışveriş listesi
# alınacak şeyi giriniz çilek
# lütfen nereden alınacağını giriniz manav
# lütfen parasını giriniz 35
# lütfen sayısını giriniz 2
# bilgiler kayıt ediliyor
# ürünün adı:çilek
# ürünün satıldığı yer:manav
# ürünün fiyatı:35
# ürünün sayısı:2
# bilgiler kayıt edildi
# toplam borç:70 tl

# %%
print(2 çilek)
# Out:
# 2 çilek

# %%
print("diyet listesi ve alacağınız kalori")
sabah_kahvaltısı=(input("lütfen kahvaltı ürünlerini giriniz"))
kalori1=int(input("lütfen kaç kalori olduğunu giriniz"))
akşam_yemeği=(input("lütfen akşam yemeğinin ürünleri giriniz"))
kalori2=int(input("lütfen akşam yemeğinin kalorisini giriniz"))
liste=[sabah_kahvaltısı,kalori1,akşam_yemeği,kalori2]
günlük_sporsuz_açık=2250-kalori1-kalori2
print("""kahvaltı_adı:{}
kalorisi1:{}
akşam_yemeği:{}
kalorisi2:{}""".format(sabah_kahvaltısı,kalori1,akşam_yemeği,kalori2))
print("veriler kayıt edildi")
print("toplam açık {} kalori".format(günlük_sporsuz_açık))
# Out:
# diyet listesi ve alacağınız kalori
# lütfen kahvaltı ürünlerini giriniz 2 yumurta, 3 zeytin , 1 dilim tam buğday ekmek
# lütfen kaç kalori olduğunu giriniz 175
# lütfen akşam yemeğinin ürünleri giriniz 1 paket haşlanmış tavuk, cacık
# lütfen akşam yemeğinin kalorisini giriniz 825
# kahvaltı_adı:2 yumurta, 3 zeytin , 1 dilim tam buğday ekmek
# kalorisi1:175
# akşam_yemeği:1 paket haşlanmış tavuk, cacık
# kalorisi2:825
# veriler kayıt edildi
# toplam açık 1250 kalori

# %%
meyve1="armut"
meyve2="ayva"
meyve3="çilek"
meyve=["armut","ayva","çilek"]
print(meyve)
# Out:
# ['armut', 'ayva', 'çilek']

# %%
meyve[2]="erik"
meyve[1]="karpuz"
print(meyve)
# Out:
# ['armut', 'karpuz', 'erik']
