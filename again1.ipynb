# %%
Irk=input("lütfen ırkınızı girin:").lower()
if Irk == "Türk":
    print("sizi aramızda görmek güzel Oğuz tözü:")
else:
    print(f"Racism is a bad thing. Welcome, our {Irk} friend.")
print(f"hoş geldiniz şeref getirdiniz {Irk} kardeşimiz:")
# Out:
# lütfen ırkınızı girin: greek
# Racism is a bad thing. Welcome, our greek friend.
# hoş geldiniz şeref getirdiniz greek kardeşimiz:

# %%
Score=int(input("Please enter your exam score:"))
if Score >= 90 and Score <= 100:
   print(f"Excellent Mr./Ms. Student you have successfully passed the exam with a score of {Score}")
elif Score >=70 and Score <=89:
     print(f"Excellent Mr./Ms. Student you passed the exam with a score of {Score} Try to put in even more effort")
elif Score >= 0 and Score <=69:
    print(f"We regret to inform you that you did not pass the exam scoring {Score} points we hope you do better next time:")
# Out:
# Please enter your exam score: 90
# Excellent Mr./Ms. Student you have successfully passed the exam with a score of 90

# %%
ali = "86"
merve =
# Out:
# 86
