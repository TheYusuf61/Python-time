# %%
score=int(input("Please enter your score:"))
ranking=int(input("Please enter your ranking:"))
if score >=85 and ranking <=25000:
   print("Congratulations, you have successfully passed the exam:")
else:
    missing_score = 85 - score
    print("We're sorry, you didn't win; please try again.:")
   
print("Congratulations, you achieved a score of {} and a ranking of {}:".format(score,ranking))
# Out:
# Please enter your score: 86
# Please enter your ranking: 16061
# Congratulations, you have successfully passed the exam:
# Congratulations, you achieved a score of 86 and a ranking of 16061:

# %%
driver_is_license_score=int(input("please enter your driver is license points:"))
if driver_is_license_score >=80:
   print("bravo driver you passed the driving test.:")
else:
    print("sorry driver you don't passed the driving test.:")
medical_report = input("please enter your medical report:")

if "healty" in medical_report.lower():
    print("bravo driver you passed the driving test:")
else:
    print("Sorry, you failed the medical check because you are unhealthy:")

print(f"Your score {driver_is_license_score} and your health status:")
# Out:
# please enter your driver is license points: 82
# bravo driver you passed the driving test.:
# please enter your medical report: healty
# bravo driver you passed the driving test:
# Your score 82 and your health status:

# %%
Name = "Yusuf"
Age = 16
print(f"Mr.{Name} happy {Age} th birthday:")
# Out:
# Mr.Yusuf happy 16 th birthday:
