# %%
yas = int(input("ehliyet için yaş girin:"))
puan = int(input("ehliyet için puan girin:"))

if yas >=18 and puan >= 70:
    print("ehliyet alabilir")

else:
     print("ehliyet alamaz")
# Out:
# ehliyet için yaş girin: 18
# ehliyet için puan girin: 70
# ehliyet alabilir

# %%
puan = int(input("yks için puan girin"))
obp = int(input("yks için obp girin"))
yks_sonuc= (obp*0.6) + puan
print("hesaplanan puan:{}".format(yks_sonuc))
if  yks_sonuc >=430:
    print("Tebrikler üniversiteye hak kazandınız")
    
else:
    print("üniversiteye giremez")
# Out:
# yks için puan girin 380
# yks için obp girin 65
# hesaplanan puan:419.0
# üniversiteye giremez

# %%
boy = int(input("lütfen boyunuzu girin:"))
kılo = int(input("lütfen kilonuzu girin:"))
puan = int(input("lütfen puanınızı girin:"))
if  boy >= 177 and boy <= 188 and kılo >= 65 and kılo <= 88 and puan >= 395:
    print("tebrikler kazandınız")

else:
     print("üzgünüz kazanamadınız")
# Out:
# lütfen boyunuzu girin: 177
# lütfen kilonuzu girin: 84
# lütfen puanınızı girin: 410
# tebrikler kazandınız
